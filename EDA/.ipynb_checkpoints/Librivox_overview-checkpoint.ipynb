# %% [markdown]
# # Librivox metadata

# %%
import pandas as pd
pd.set_option('mode.chained_assignment', None)
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.gridspec as gridspec
from matplotlib import rcParams
import seaborn as sns
import numpy as np
import datetime as dt
from bs4 import BeautifulSoup
import requests


from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import warnings
warnings.filterwarnings('ignore')

# figure size in inches
rcParams['figure.figsize'] = 11.7,8.27
params = {'legend.fontsize': 20,
          'legend.handlelength': 2}
plt.rcParams.update(params)

#add data path
path='../data/'
# Out:
# /Users/saijananiganesan/anaconda3/lib/python3.6/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ### Useful functions

# %%
def fetch_and_clean_data(path=path,fname='librivox_synopsis_df_genre.csv'):
    df=pd.read_csv(path+fname)
    cleaned=df.drop('Unnamed: 0',1)
    cleaned=cleaned[cleaned['Language']=="English"]
    return cleaned

# %%
df=fetch_and_clean_data()
df.info()
len(df['Book Name'].unique())
df['URL'].unique()[0]
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12946 entries, 0 to 12945
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Book Name      12946 non-null  object
#  1   Book Synopsis  12915 non-null  object
#  2   Language       12946 non-null  object
#  3   URL            12427 non-null  object
#  4   Time           12420 non-null  object
#  5   Authors        12946 non-null  object
#  6   Genre          12946 non-null  object
# dtypes: object(7)
# memory usage: 809.1+ KB
# 12805
# 'https://librivox.org/letters-of-two-brides-by-honore-de-balzac/'
#                                                Book Name  \
# 0                                  Letters of Two Brides
# 1                                            Bleak House
# 2                                         Penguin Island
# 3                                  This Side of Paradise
# 4                                          Secret Garden
# ...                                                  ...
# 12941  Neighbourhood – A Year’s Life in and About an ...
# 12942                  History of New England, 1630-1649
# 12943                Vietnam: The advisory years to 1965
# 12944              Short Nonfiction Collection, Vol. 077
# 12945                            Study of British Genius
#
#                                            Book Synopsis Language  \
# 0      Letters of Two Brides is an epistolary novel. ...  English
# 1      <p>Bleak House is the ninth novel by Charles D...  English
# 2      <p>The novel (original French title -- L'Île d...  English
# 3      <p>This Side of Paradise is the debut novel of...  English
# 4      Mary Lennox is a spoiled, middle-class, self-c...  English
# ...                                                  ...      ...
# 12941  If you love the quiet of the country - the rea...  English
# 12942                                                NaN  English
# 12943  This book explains the policy of the United St...  English
# 12944                          - Summary by Sue Anderson  English
# 12945  The psychological and anthropological characte...  English
#
#                                                      URL      Time  \
# 0      https://librivox.org/letters-of-two-brides-by-...   9:09:20
# 1      https://librivox.org/bleak-house-by-charles-di...  43:30:19
# 2      https://librivox.org/penguin-island-by-anatole...   9:04:31
# 3      https://librivox.org/this-side-of-paradise-by-...   8:56:24
# 4      https://librivox.org/the-secret-garden-by-fran...   9:08:25
# ...                                                  ...       ...
# 12941                                                NaN       NaN
# 12942                                                NaN       NaN
# 12943                                                NaN       NaN
# 12944                                                NaN       NaN
# 12945                                                NaN       NaN
#
#                        Authors                   Genre
# 0             Honoré de Balzac      Epistolary Fiction
# 1              Charles Dickens         General Fiction
# 2               Anatole France                  Satire
# 3          F. Scott Fitzgerald   Published 1900 onward
# 4      Frances Hodgson Burnett      Children's Fiction
# ...                        ...                     ...
# 12941         Tickner Edwardes                    None
# 12942            John Winthrop                    None
# 12943           Robert Futrell                    None
# 12944                  Various                    None
# 12945           Havelock Ellis                    None
#
# [12946 rows x 7 columns]

# %% [markdown]
# ### A quick overview of the dataset.

# %%
def apply_cat(cat):
    if 'fiction' in cat.lower():
        return 'Fiction'
    elif 'poetry' in cat.lower():
        return 'Poetry'
    elif 'histor' in cat.lower():
        return 'History'
    elif 'health' in cat.lower():
        return 'Health&Fitness'
    elif 'humor' in cat.lower():
        return 'Humor'
    elif 'law' in cat.lower():
        return 'Law'
    elif 'published' in cat.lower():
        return 'None'
    elif 'bible' in cat.lower():
        return 'Christianity'
    elif 'christ' in cat.lower():
        return 'Christianity'
    else:
        return cat
    
df['Categories']=df['Genre'].apply(apply_cat)
df
# Out:
#                                                Book Name  \
# 0                                  Letters of Two Brides
# 1                                            Bleak House
# 2                                         Penguin Island
# 3                                  This Side of Paradise
# 4                                          Secret Garden
# ...                                                  ...
# 12941  Neighbourhood – A Year’s Life in and About an ...
# 12942                  History of New England, 1630-1649
# 12943                Vietnam: The advisory years to 1965
# 12944              Short Nonfiction Collection, Vol. 077
# 12945                            Study of British Genius
#
#                                            Book Synopsis Language  \
# 0      Letters of Two Brides is an epistolary novel. ...  English
# 1      <p>Bleak House is the ninth novel by Charles D...  English
# 2      <p>The novel (original French title -- L'Île d...  English
# 3      <p>This Side of Paradise is the debut novel of...  English
# 4      Mary Lennox is a spoiled, middle-class, self-c...  English
# ...                                                  ...      ...
# 12941  If you love the quiet of the country - the rea...  English
# 12942                                                NaN  English
# 12943  This book explains the policy of the United St...  English
# 12944                          - Summary by Sue Anderson  English
# 12945  The psychological and anthropological characte...  English
#
#                                                      URL      Time  \
# 0      https://librivox.org/letters-of-two-brides-by-...   9:09:20
# 1      https://librivox.org/bleak-house-by-charles-di...  43:30:19
# 2      https://librivox.org/penguin-island-by-anatole...   9:04:31
# 3      https://librivox.org/this-side-of-paradise-by-...   8:56:24
# 4      https://librivox.org/the-secret-garden-by-fran...   9:08:25
# ...                                                  ...       ...
# 12941                                                NaN       NaN
# 12942                                                NaN       NaN
# 12943                                                NaN       NaN
# 12944                                                NaN       NaN
# 12945                                                NaN       NaN
#
#                        Authors                   Genre Categories
# 0             Honoré de Balzac      Epistolary Fiction    Fiction
# 1              Charles Dickens         General Fiction    Fiction
# 2               Anatole France                  Satire     Satire
# 3          F. Scott Fitzgerald   Published 1900 onward       None
# 4      Frances Hodgson Burnett      Children's Fiction    Fiction
# ...                        ...                     ...        ...
# 12941         Tickner Edwardes                    None       None
# 12942            John Winthrop                    None       None
# 12943           Robert Futrell                    None       None
# 12944                  Various                    None       None
# 12945           Havelock Ellis                    None       None
#
# [12946 rows x 8 columns]

# %%
categories=df.groupby(['Categories']).count().reset_index().sort_values(by='Book Name',ascending=False)

categories = categories.drop(categories[categories.Genre ==' '].index)

categories['Categories'].unique()
# Out:
# array(['Fiction', 'Poetry', 'None', 'Christianity',
#        ' Myths, Legends & Fairy Tales', 'History',
#        ' Biography & Autobiography', ' Single author',
#        ' Animals & Nature', ' Action & Adventure', ' Short Stories',
#        ' Essays & Short Works', ' Romance', ' Anthologies',
#        ' Travel & Geography', ' General', ' Plays', ' Memoirs',
#        ' Tragedy', ' War & Military', ' Single Author Collections',
#        ' Comedy', ' Nature', ' Religion', ' Family', ' Early Modern',
#        ' Ancient', ' King James Version', ' Modern (19th C)', 'Humor',
#        ' Short works', ' Political Science',
#        " Young's Literal Translation", ' Satire', ' Westerns', ' Cooking',
#        ' Drama', ' Other religions', 'Law', ' Antiquity', ' Modern',
#        ' Self-Help', ' Science',
#        ' Social Science (Culture & Anthropology)', ' Philosophy',
#        ' Exploration', ' True Crime', ' ', ' Literary Collections',
#        ' Plays, Satire',
#        ' War & Military, Biography & Autobiography, Political Science',
#        'Health&Fitness', ' Family Life', ' Psychology',
#        ' War & Military, Memoirs', ' Animals',
#        ' Biography & Autobiography, Modern (19th C)',
#        ' Business & Economics',
#        ' War & Military, Biography & Autobiography',
#        ' Suspense, Espionage, Political & Thrillers', ' School',
#        ' Art, Design & Architecture', ' Medical', ' Douay-Rheims Version',
#        ' Dramatic Readings', ' Astronomy, Physics & Mechanics',
#        ' Education', ' Epics', ' Travel & Geography, Memoirs',
#        ' War & Military, Modern (19th C)',
#        ' Literary Collections, Political Science',
#        ' Plays, Drama, Tragedy', ' Classics (Greek & Latin Antiquity)',
#        ' Political Science, Early Modern',
#        ' Anthologies, Anthologies, Literary Collections',
#        ' Literary Criticism', ' War & Military, Modern (20th C)',
#        ' Biography & Autobiography, Music', ' Sonnets',
#        ' Single author, Lyric', ' Narratives', ' Writing & Linguistics',
#        ' Earth Sciences', ' Action & Adventure, Animals & Nature',
#        ' Language learning', ' Music',
#        ' General, Biography & Autobiography',
#        ' Biography & Autobiography, True Crime', ' Life Sciences',
#        ' Weymouth New Testament', ' Technology & Engineering',
#        ' Dramatic Readings, Romance',
#        ' Myths, Legends & Fairy Tales, Myths, Legends & Fairy Tales',
#        ' Letters', ' Biography & Autobiography, Antiquity',
#        ' Animals & Nature, Myths, Legends & Fairy Tales',
#        ' Philosophy, Modern', ' Family, Religion', ' Comedy, Tragedy',
#        ' Religion, Religion', ' Sports & Recreation', ' Modern (20th C)',
#        ' Action & Adventure, General', ' Memoirs, Modern (19th C)',
#        ' Comedy, Romance', ' Ballads',
#        ' War & Military, Memoirs, Modern (19th C)',
#        ' Family Life, Romance',
#        ' Essays & Short Works, Literary Criticism', ' Essays',
#        ' Reference, Travel & Geography',
#        ' Classics (Greek & Latin Antiquity), Plays', ' Contemporary',
#        ' Romance, Suspense, Espionage, Political & Thrillers',
#        ' War & Military, Early Modern', ' Sagas',
#        ' Animals, Nature, Life Sciences',
#        ' Political Science, Social Science (Culture & Anthropology)',
#        ' Family & Relationships', ' Chemistry', ' Reference',
#        ' Philosophy, Ancient', ' Plays, Comedy',
#        ' Dramatic Readings, Family', ' Family, General',
#        ' Nature, Travel & Geography', ' Single author, Sonnets',
#        ' Classics (Greek & Latin Antiquity), Tragedy', ' Performing Arts',
#        ' Plays, Tragedy', ' Westerns, Single Author Collections',
#        ' Single author, War & Military', ' Philosophy, Religion',
#        ' Essays & Short Works, Modern (19th C)',
#        ' Animals & Nature, Family',
#        ' Travel & Geography, Modern (19th C)',
#        ' Political Science, Modern (19th C)', ' Mathematics',
#        ' Animals, Nature, Reference', ' Action & Adventure, Family',
#        ' Reference, Early Modern', ' War & Military, Medical',
#        ' Dramatic Readings, Animals & Nature', ' Education, Psychology',
#        ' Classics (Greek & Latin Antiquity), Comedy',
#        ' Biography & Autobiography, Travel & Geography', ' Gardening',
#        ' Essays & Short Works, Political Science',
#        ' Art, Design & Architecture, Biography & Autobiography',
#        ' Nature, Earth Sciences',
#        ' Biography & Autobiography, Modern (20th C)',
#        ' Crafts & Hobbies, Cooking', ' Lyric', ' Single author, Ballads',
#        ' Essays & Short Works, Travel & Geography', ' General, General',
#        ' Dramatic Readings, Myths, Legends & Fairy Tales',
#        ' Essays, Early Modern', ' Single author, Narratives', ' Erotica',
#        ' Elegies & Odes', ' Early Modern, Exploration', ' Family, School',
#        ' General, Religion',
#        ' Social Science (Culture & Anthropology), Modern (20th C)',
#        ' Short Stories, General, General',
#        ' Essays & Short Works, Political Science, Social Science (Culture & Anthropology)',
#        ' Biography & Autobiography, Early Modern',
#        ' Religion, Atheism & Agnosticism',
#        ' War & Military, Political Science, Modern (19th C)',
#        ' Myths, Legends & Fairy Tales, Narratives', ' Romance, Satire',
#        ' Action & Adventure, Religion',
#        ' Myths, Legends & Fairy Tales, General',
#        ' Biography & Autobiography, Essays & Short Works',
#        ' Westerns, Action & Adventure', ' Psychology, Memoirs',
#        ' Myths, Legends & Fairy Tales, Short Stories',
#        ' Myths, Legends & Fairy Tales, Tragedy',
#        ' Classics (Greek & Latin Antiquity), Epics', ' Plays, Romance',
#        ' Classics (Greek & Latin Antiquity), Myths, Legends & Fairy Tales',
#        ' Religion, Biography & Autobiography', ' Psychology, Science',
#        ' Art, Design & Architecture, Travel & Geography',
#        ' Animals, Nature',
#        ' Essays & Short Works, Social Science (Culture & Anthropology)',
#        ' Memoirs, Modern (20th C)', ' Memoirs, Exploration',
#        ' Biography & Autobiography, Performing Arts', ' Crafts & Hobbies',
#        ' Plays, Myths, Legends & Fairy Tales',
#        ' Biography & Autobiography, Literary Criticism',
#        ' Nature, Science, Travel & Geography', ' Nature, Memoirs',
#        ' Short Stories, Essays & Short Works',
#        ' Family & Relationships, Social Science (Culture & Anthropology)',
#        ' Romance, Short Stories', ' Political Science, Memoirs',
#        ' Family & Relationships, Psychology', ' Short Stories, Westerns',
#        ' Animals, Sports & Recreation', ' Philosophy, Political Science',
#        ' Short works, General', ' Philosophy, Psychology, Self-Help',
#        ' Philosophy, Social Science (Culture & Anthropology)',
#        ' Animals, Essays & Short Works, Nature', ' Nature, Gardening',
#        ' Games', ' Family Life, School', ' General, Short works',
#        ' Animals & Nature, Short works', ' Medieval',
#        ' Satire, Early Modern', ' Memoirs, Letters',
#        ' Modern (19th C), Exploration', ' Religion, Early Modern',
#        ' Religion, Antiquity', ' Music, Religion', ' House & Home',
#        ' Reference, Modern (19th C)', ' Reference, Life Sciences',
#        ' Family Life, Short Stories', ' General, Reference',
#        ' Reference, Language learning',
#        ' Myths, Legends & Fairy Tales, Plays', ' Science, Science',
#        ' Science, Social Science (Culture & Anthropology)',
#        ' Myths, Legends & Fairy Tales, Religion', ' Reference, Cooking',
#        ' Myths, Legends & Fairy Tales, Sagas',
#        ' Family Life, Single Author Collections', ' Psychology, Modern',
#        ' Modern, Other religions', ' Plays, Drama',
#        ' True Crime, Modern (19th C)',
#        ' Dramatic Readings, Action & Adventure',
#        ' Social Science (Culture & Anthropology), Modern (19th C)',
#        ' Contemporary, Other religions',
#        ' Education, Science, Modern (19th C)', ' Education, Reference',
#        ' Crafts & Hobbies, Performing Arts',
#        ' Education, Performing Arts',
#        ' Social Science (Culture & Anthropology), Travel & Geography',
#        ' Classics (Greek & Latin Antiquity), Ancient',
#        ' War & Military, Letters', ' Business & Economics, Ancient',
#        ' Early Modern, Modern (19th C)', ' Epics, Narratives',
#        ' Action & Adventure, School',
#        ' Biography & Autobiography, Social Science (Culture & Anthropology)',
#        ' Biography & Autobiography, Memoirs',
#        ' Dramatic Readings, Action & Adventure, Animals & Nature',
#        ' War & Military, Memoirs, Letters',
#        ' Biography & Autobiography, Political Science',
#        ' Dramatic Readings, Religion',
#        ' Biography & Autobiography, Political Science, Modern (19th C)',
#        ' Biography & Autobiography, Religion',
#        ' Dramatic Readings, Family Life',
#        ' War & Military, Biography & Autobiography, Modern (19th C)',
#        ' Transportation', ' Art, Design & Architecture, Antiquity',
#        ' Arts', ' Classics (Greek & Latin Antiquity), Philosophy',
#        ' Art, Design & Architecture, Memoirs, Modern (19th C)',
#        ' Art, Design & Architecture, Essays & Short Works',
#        ' Art, Design & Architecture, Biography & Autobiography, Early Modern',
#        ' War & Military, Biography & Autobiography, Early Modern',
#        ' Action & Adventure, Animals & Nature, Short works',
#        ' Atheism & Agnosticism', ' Erotica, Biography & Autobiography',
#        ' Action & Adventure, Myths, Legends & Fairy Tales',
#        ' Travel & Geography, Other religions', ' Comedy, Satire',
#        ' Essays & Short Works, Modern',
#        ' Biography & Autobiography, Astronomy, Physics & Mechanics',
#        ' Essays & Short Works, Nature', ' Animals & Nature, General',
#        ' War & Military, Art, Design & Architecture, Biography & Autobiography',
#        ' Psychology, Social Science (Culture & Anthropology)',
#        ' Psychology, Self-Help, Modern', ' War & Military, Antiquity',
#        ' War & Military, Biography & Autobiography, Medical',
#        ' War & Military, Medical, Memoirs',
#        ' War & Military, Medical, Modern (20th C)',
#        ' Reference, Social Science (Culture & Anthropology), Other religions',
#        ' Reference, Crafts & Hobbies',
#        ' War & Military, Essays & Short Works, Political Science',
#        ' War & Military, Biography & Autobiography, Family & Relationships',
#        ' War & Military, Education', ' Religion, Ancient',
#        ' War & Military, Business & Economics, Modern (20th C)',
#        ' War & Military, Biography & Autobiography, Literary Criticism',
#        ' War & Military, Memoirs, Antiquity',
#        ' War & Military, Biography & Autobiography, Nature',
#        ' Animals, Cooking',
#        ' War & Military, Business & Economics, Education',
#        ' Single Author Collections, Literary Collections',
#        ' Psychology, Self-Help, Contemporary', ' Plays, Short Stories',
#        ' Political Science, Early Modern, Modern (19th C)',
#        ' War & Military, Travel & Geography, Transportation',
#        ' Political Science, Ancient', ' War & Military, True Crime',
#        ' Animals, Education, Nature',
#        ' Plays, Suspense, Espionage, Political & Thrillers',
#        ' Plays, Satire, Satire', ' War & Military, Travel & Geography',
#        ' Writing & Linguistics, Ancient', ' Plays, Romance, Satire',
#        ' Action & Adventure, Myths, Legends & Fairy Tales, Comedy',
#        ' Plays, Romance, Drama',
#        ' Action & Adventure, Animals & Nature, Family', ' Plays, Music',
#        ' War & Military, Travel & Geography, Memoirs',
#        ' Political Science, Memoirs, Modern (20th C)',
#        ' War & Military, Memoirs, Early Modern',
#        ' War & Military, Religion, Early Modern',
#        ' Psychology, Self-Help',
#        ' Psychology, Religion, Social Science (Culture & Anthropology)',
#        ' War & Military, Memoirs, Modern (20th C)',
#        ' Psychology, Ancient',
#        ' War & Military, Modern (20th C), Letters',
#        ' Political Science, Social Science (Culture & Anthropology), Travel & Geography',
#        ' Political Science, Science', ' Political Science, Modern',
#        ' Political Science, Psychology, Social Science (Culture & Anthropology)',
#        ' Political Science, Psychology, Life Sciences',
#        ' Political Science, Other religions',
#        ' Political Science, Modern (20th C)',
#        ' War & Military, Social Science (Culture & Anthropology), Memoirs',
#        ' War & Military, Technology & Engineering',
#        ' War & Military, Political Science, Antiquity',
#        ' Travel & Geography, Modern (20th C)', ' Religion, Modern',
#        ' Social Science (Culture & Anthropology), Technology & Engineering',
#        ' Social Science (Culture & Anthropology), Early Modern, Modern (19th C)',
#        ' Social Science (Culture & Anthropology), Life Sciences',
#        ' Animals & Nature, Myths, Legends & Fairy Tales, Short works',
#        ' Social Science (Culture & Anthropology), Memoirs',
#        ' Science, Travel & Geography',
#        ' Social Science (Culture & Anthropology), Modern (19th C), Modern (20th C)',
#        ' Science, Technology & Engineering', ' Science, Self-Help',
#        ' Animals & Nature, Religion', ' Science, Reference, Antiquity',
#        ' Science, Nature',
#        ' Social Science (Culture & Anthropology), Travel & Geography, Memoirs',
#        ' Science, Modern (20th C)', ' Science, Earth Sciences',
#        ' Science, Animals',
#        ' Social Science (Culture & Anthropology), True Crime',
#        ' Self-Help, Cooking',
#        ' Social Science (Culture & Anthropology), Early Modern',
#        ' Self-Help, Essays, Ancient', ' Self-Help, Modern (20th C)',
#        ' Single author, Free Verse',
#        ' Single author, Literary Collections',
#        ' Animals & Nature, Myths, Legends & Fairy Tales, Family',
#        ' Single author, Modern (19th C)',
#        ' Short Stories, Westerns, War & Military',
#        ' Single author, Political Science',
#        ' Short Stories, Single Author Collections',
#        ' Single author, Self-Help',
#        ' Single author, Single Author Collections',
#        ' Animals & Nature, Family, General', ' Short Stories, General',
#        ' Social Science (Culture & Anthropology), Antiquity, Other religions',
#        ' Short Stories, Family, General',
#        ' Short Stories, Biography & Autobiography, Essays & Short Works',
#        ' Animals & Nature, Myths, Legends & Fairy Tales, General',
#        ' Social Science (Culture & Anthropology), Writing & Linguistics, Modern',
#        ' Sonnets, Nature', ' True Crime, Memoirs, Exploration',
#        ' Religion, Social Science (Culture & Anthropology)',
#        ' Romance, Sagas', ' Romance, Music', ' Romance, General',
#        ' Romance, Family, General', ' Romance, Anthologies',
#        ' Animals, Biography & Autobiography',
#        ' Religion, Travel & Geography', ' Religion, Short works',
#        ' Sports & Recreation, Modern (20th C), Exploration',
#        ' Religion, Self-Help', ' Single Author Collections, Memoirs',
#        ' Religion, School', ' Ancient, Other religions',
#        ' True Crime, Early Modern', ' Religion, Modern (19th C)',
#        ' True Crime, Memoirs',
#        ' Travel & Geography, Memoirs, Modern (20th C)',
#        ' Romance, School', ' Travel & Geography, Memoirs, Letters',
#        ' Romance, Single author, Lyric',
#        ' Satire, Westerns, Single Author Collections',
#        ' Sports & Recreation, Travel & Geography',
#        ' Sports & Recreation, Travel & Geography, Memoirs',
#        ' Technology & Engineering, Earth Sciences',
#        ' Technology & Engineering, Exploration', ' Satire, Tragedy',
#        ' Technology & Engineering, Memoirs, Modern (20th C)',
#        ' Satire, Short Stories', ' Satire, Literary Collections',
#        ' Satire, Essays & Short Works, Philosophy',
#        ' Technology & Engineering, Modern (20th C), Earth Sciences',
#        ' Sagas, Myths, Legends & Fairy Tales',
#        ' Travel & Geography, Antiquity', ' Romance, Westerns',
#        ' Travel & Geography, Earth Sciences',
#        ' Single author, Biography & Autobiography',
#        ' Anthologies, Single author', ' Plays, Comedy, Tragedy',
#        ' Dramatic Readings, King James Version', ' Early Modern, Letters',
#        ' Early Modern, Essays, Letters', ' Early Modern, Cooking',
#        ' Dramatic Readings, Short works', ' Dramatic Readings, School',
#        ' Dramatic Readings, Satire',
#        ' Dramatic Readings, Romance, Single Author Collections',
#        ' Dramatic Readings, Romance, Family', ' Dramatic Readings, Plays',
#        ' Dramatic Readings, Narratives',
#        ' Dramatic Readings, Myths, Legends & Fairy Tales, Narratives',
#        ' Dramatic Readings, Family Life, Family',
#        ' Essays & Short Works, Political Science, Modern',
#        ' Dramatic Readings, Erotica', ' Drama, Romance',
#        ' Drama, Modern, Other religions', ' Drama, Antiquity, Ancient',
#        ' Anthologies, Ballads', ' Anthologies, Elegies & Odes',
#        ' Contemporary, Atheism & Agnosticism', ' Comedy, Drama',
#        ' Anthologies, Literary Collections',
#        ' Classics (Greek & Latin Antiquity), War & Military, Astronomy, Physics & Mechanics',
#        ' Classics (Greek & Latin Antiquity), Single author, Epics',
#        ' Early Modern, Life Sciences', ' Early Modern, Modern',
#        ' Early Modern, Other religions', ' Earth Sciences, Life Sciences',
#        ' Essays & Short Works, Philosophy',
#        ' Essays & Short Works, Modern (20th C)',
#        ' Essays & Short Works, Memoirs',
#        ' Essays & Short Works, Medical, Social Science (Culture & Anthropology)',
#        ' Essays & Short Works, Mathematics',
#        ' Essays & Short Works, Literary Collections',
#        ' Essays & Short Works, Family & Relationships',
#        ' Essays & Short Works, Contemporary',
#        ' Essays & Short Works, Antiquity',
#        ' Essays & Short Works, Ancient', ' Anthologies, Anthologies',
#        ' Erotica, Single author', ' Erotica, Romance',
#        ' Erotica, Ancient', ' Epics, Other religions',
#        ' Education, Writing & Linguistics, Modern',
#        ' Education, Technology & Engineering',
#        ' Education, Social Science (Culture & Anthropology)',
#        ' Education, Self-Help', ' Education, Political Science',
#        ' Education, Philosophy, Psychology',
#        ' Education, Music, Self-Help', ' Education, Literary Criticism',
#        ' Classics (Greek & Latin Antiquity), Short Stories',
#        ' Classics (Greek & Latin Antiquity), Science',
#        ' Classics (Greek & Latin Antiquity), Satire',
#        ' Biography & Autobiography, Memoirs, Modern (20th C)',
#        ' Biography & Autobiography, Medical, Modern (19th C)',
#        ' Biography & Autobiography, Medical',
#        ' Biography & Autobiography, Literary Criticism, Writing & Linguistics',
#        ' Biography & Autobiography, Literary Criticism, Political Science',
#        ' Biography & Autobiography, Literary Criticism, Performing Arts',
#        ' Biography & Autobiography, Literary Criticism, Modern (19th C)',
#        ' Biography & Autobiography, Literary Collections',
#        ' Biography & Autobiography, Letters',
#        ' Biography & Autobiography, Family & Relationships',
#        ' Biography & Autobiography, Essays & Short Works, Political Science',
#        ' Biography & Autobiography, Early Modern, Exploration',
#        ' Biography & Autobiography, Atheism & Agnosticism',
#        ' Biography & Autobiography, Ancient, Other religions',
#        ' Biography & Autobiography, Ancient',
#        ' Anthologies, Lyric, Sonnets', ' Arts, Crafts & Hobbies',
#        ' Arts, Biography & Autobiography',
#        ' Art, Design & Architecture, Social Science (Culture & Anthropology), Memoirs',
#        ' Art, Design & Architecture, Philosophy, Memoirs',
#        ' Art, Design & Architecture, Crafts & Hobbies, Nature',
#        ' Art, Design & Architecture, Astronomy, Physics & Mechanics',
#        ' Antiquity, Other religions', ' Anthologies, Modern (19th C)',
#        ' Biography & Autobiography, Medical, Modern (20th C)',
#        ' Biography & Autobiography, Modern',
#        ' Classics (Greek & Latin Antiquity), Reference',
#        ' Biography & Autobiography, Modern (19th C), Modern (20th C)',
#        ' Classics (Greek & Latin Antiquity), Political Science',
#        ' Classics (Greek & Latin Antiquity), Myths, Legends & Fairy Tales, Single Author Collections',
#        ' Classics (Greek & Latin Antiquity), Essays & Short Works',
#        ' Classics (Greek & Latin Antiquity), Education',
#        ' Classics (Greek & Latin Antiquity), Dramatic Readings, Satire',
#        ' Classics (Greek & Latin Antiquity), Dramatic Readings, Philosophy',
#        ' Classics (Greek & Latin Antiquity), Dramatic Readings, Myths, Legends & Fairy Tales',
#        ' Classics (Greek & Latin Antiquity), Drama',
#        ' Classics (Greek & Latin Antiquity), Biography & Autobiography, Essays & Short Works',
#        ' Classics (Greek & Latin Antiquity), Biography & Autobiography, Antiquity',
#        ' Classics (Greek & Latin Antiquity), Biography & Autobiography',
#        ' Classics (Greek & Latin Antiquity), Antiquity',
#        ' Classics (Greek & Latin Antiquity), Ancient, Life Sciences',
#        ' Chemistry, Earth Sciences',
#        ' Business & Economics, Social Science (Culture & Anthropology)',
#        ' Business & Economics, Self-Help',
#        ' Business & Economics, Political Science, Contemporary',
#        ' Business & Economics, Political Science',
#        ' Business & Economics, House & Home',
#        ' Biography & Autobiography, Science',
#        ' Biography & Autobiography, Religion, Atheism & Agnosticism',
#        ' Biography & Autobiography, Nature',
#        ' Biography & Autobiography, Music, Performing Arts',
#        ' Essays & Short Works, Philosophy, Religion',
#        ' Essays & Short Works, Reference, Modern (19th C)',
#        ' Plays, Biography & Autobiography',
#        ' Myths, Legends & Fairy Tales, Family, Religion',
#        ' Narratives, Travel & Geography',
#        ' Narratives, Literary Criticism, Writing & Linguistics',
#        ' Myths, Legends & Fairy Tales, Westerns',
#        ' Myths, Legends & Fairy Tales, Single Author Collections',
#        ' Myths, Legends & Fairy Tales, Satire',
#        ' Myths, Legends & Fairy Tales, Sagas, Other religions',
#        ' Myths, Legends & Fairy Tales, Romance',
#        ' Myths, Legends & Fairy Tales, Religion, Antiquity',
#        ' Myths, Legends & Fairy Tales, Plays, Drama',
#        ' Myths, Legends & Fairy Tales, General, School',
#        ' Myths, Legends & Fairy Tales, General, Biography & Autobiography',
#        ' Myths, Legends & Fairy Tales, Antiquity',
#        ' Essays & Short Works, Self-Help, Contemporary',
#        ' Myths, Legends & Fairy Tales, Animals & Nature',
#        ' Myths, Legends & Fairy Tales, Ancient', ' Animals, Memoirs',
#        ' Music, Early Modern', ' Anthologies, Travel & Geography',
#        ' Modern (20th C), Transportation',
#        ' Modern (19th C), Transportation',
#        ' Modern (19th C), Other religions',
#        ' Modern (19th C), Modern (20th C)', ' Memoirs, Other religions',
#        ' Memoirs, Modern', ' Animals, Medical, Modern (19th C)',
#        ' Nature, Earth Sciences, Life Sciences', ' Nature, Exploration',
#        ' Nature, Memoirs, Exploration',
#        ' Philosophy, Political Science, Psychology',
#        ' Philosophy, Other religions', ' Philosophy, Memoirs',
#        ' Philosophy, Early Modern', ' Animals, Gardening',
#        ' Performing Arts, Sports & Recreation',
#        ' Performing Arts, Social Science (Culture & Anthropology), Memoirs',
#        ' Performing Arts, Social Science (Culture & Anthropology)',
#        ' Performing Arts, Memoirs', ' Animals, Life Sciences',
#        ' Nature, Travel & Geography, Letters',
#        ' Nature, Travel & Geography, Exploration',
#        ' Nature, Travel & Geography, Earth Sciences',
#        ' Nature, Technology & Engineering, Modern (20th C)',
#        ' Nature, Sports & Recreation, Travel & Geography',
#        ' Nature, Social Science (Culture & Anthropology)',
#        ' Nature, Science, Technology & Engineering', ' Nature, Science',
#        ' Nature, Reference, Gardening', ' Nature, Reference',
#        ' Nature, Modern (20th C)',
#        ' Nature, Modern (19th C), Life Sciences',
#        ' Nature, Modern (19th C)', ' Memoirs, Life Sciences',
#        ' Memoirs, Early Modern, Modern (19th C)',
#        ' Memoirs, Early Modern', ' General, Modern (19th C)',
#        ' General, Early Modern', ' General, Cooking',
#        ' General, Antiquity', ' General, Animals', ' Animals, Religion',
#        ' Free Verse', ' Family, Religion, School',
#        ' Family Life, Westerns', ' Family Life, Romance, Sagas',
#        ' Family Life, General', ' Family Life, Gardening',
#        ' Family Life, Family', ' Family Life, Drama',
#        ' Family Life, Business & Economics, Education',
#        ' Family Life, Biography & Autobiography',
#        ' Family & Relationships, Travel & Geography',
#        ' Family & Relationships, Reference, Social Science (Culture & Anthropology)',
#        ' Family & Relationships, Philosophy',
#        ' Family & Relationships, Memoirs',
#        ' Family & Relationships, Medical', ' Animals, Science',
#        ' Essays & Short Works, Writing & Linguistics',
#        ' Essays & Short Works, Technology & Engineering, Memoirs',
#        ' General, Letters', ' General, Nature',
#        ' Memoirs, Atheism & Agnosticism', ' General, War & Military',
#        ' Memoirs, Astronomy, Physics & Mechanics',
#        ' Animals, Nature, Memoirs', ' Medieval, Early Modern',
#        ' Medical, Technology & Engineering', ' Medical, Psychology',
#        ' Medical, Philosophy, Social Science (Culture & Anthropology)',
#        ' Medical, Modern (20th C)', ' Medical, Memoirs',
#        ' Medical, Life Sciences', ' Medical, Contemporary',
#        ' Medical, Astronomy, Physics & Mechanics, Life Sciences',
#        ' Mathematics, Philosophy, Technology & Engineering',
#        ' Mathematics, Astronomy, Physics & Mechanics, Earth Sciences',
#        ' Mathematics, Astronomy, Physics & Mechanics',
#        ' Lyric, Social Science (Culture & Anthropology), Medieval',
#        ' Literary Criticism, Writing & Linguistics',
#        ' Literary Criticism, Philosophy, Early Modern',
#        ' Literary Criticism, Philosophy', ' Literary Criticism, Essays',
#        ' Literary Criticism, Antiquity',
#        ' Literary Collections, Social Science (Culture & Anthropology)',
#        ' Animals, Nature, Science', ' House & Home, Cooking, Gardening',
#        ' Medical, Science'], dtype=object)

# %%
f, ax1 = plt.subplots(1,1,figsize=(10, 7));
sns.set_color_codes("pastel");
sns.barplot(x="Book Name", y="Categories", data=categories.iloc[:10,:], color="g",ax=ax1);
ax1.set(ylabel="",xlabel="Total Number of Books",title='Total books by categories');
ax1.grid(True);
plt.tight_layout();
sns.despine(left=True, bottom=True);
